# %%
# !git clone https://github.com/tenmongit/loan-approval-project-mlfinal.git
# %cd loan-approval-project-mlfinal

import pandas as pd
df = pd.read_csv("data/raw/loan_data.csv")
df.head()
# Out:
# Cloning into 'loan-approval-project-mlfinal'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 67 (delta 22), reused 22 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (67/67), 67.87 KiB | 4.85 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# /content/loan-approval-project-mlfinal
#               name              city  income  credit_score  loan_amount  \
# 0     Allison Hill         East Jill  113810           389        39698
# 1     Brandon Hall     New Jamesside   44592           729        15446
# 2     Rhonda Smith      Lake Roberto   33278           584        11189
# 3  Gabrielle Davis  West Melanieview  127196           344        48823
# 4     Valerie Gray         Mariastad   66048           496        47174
#
#    years_employed  points  loan_approved
# 0              27    50.0          False
# 1              28    55.0          False
# 2              13    45.0          False
# 3              29    50.0          False
# 4               4    25.0          False
